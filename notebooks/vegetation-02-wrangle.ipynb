# %% [markdown]
# # Water Rights Restored to the Gila River
#
# The impacts of irrigation on vegetation health in the Gila River Valley
#
# Elsa Culler
# Nate Quarderer
# 2025-07-09
#
# # STEP 2: Wrangle Raster Data
#
# # STEP 0: Set up
#
# To get started on this notebook, you’ll need to restore any variables
# from previous notebooks to your workspace. To save time and memory, make
# sure to specify which variables you want to load.

# %%
# %store -r

# %% [markdown]
# You will also need to import any libraries you are using in this
# notebook, since they won’t carry over from the previous notebook:

# %%
# Import libraries
import json
from glob import glob

import earthpy
import hvplot.xarray
import rioxarray as rxr
import xarray as xr

import pandas as pd
import hvplot.pandas
import geopandas as gpd
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='p1004'>
#   <div id="ff53bf45-eee0-467f-ac8e-f310a4fe0fb7" data-root-id="p1004" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"9f8fe98b-8b85-423a-aa37-895477f4ab15":{"version":"3.7.3","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"p1004"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"p1005","attributes":{"plot_id":"p1004","comm_id":"12695b60844b46d6a53d88fc4878d6da","client_comm_id":"687ec2007f524108b37e7c93864f400a"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"max_notifications","kind":"Any","default":5},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_rendered","kind":"Any","default":false},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"TemplateEditor1","properties":[{"name":"layout","kind":"Any","default":[]}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"ReactiveESM1","properties":[{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"JSComponent1","properties":[{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"mode ...
#   var render_items = [{"docid":"9f8fe98b-8b85-423a-aa37-895477f4ab15","roots":{"p1004":"ff53bf45-eee0-467f-ac8e-f310a4fe0fb7"},"root_ids":["p1004"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %% [markdown]
# ## Load in NDVI data
#
# Now you need to load all the downloaded files into Python. Let’s start
# by getting all the file names. You will also need to extract the date
# from the filename. Check out [the lesson on getting information from
# filenames in the
# textbook](https://www.earthdatascience.org/courses/intro-to-earth-data-science/write-efficient-python-code/loops/data-workflows-with-loops/).
#
# Instead of writing out the names of all the files you want, you can use
# the `glob` utility to find all files that match a **pattern** formed
# with the **wildcard** character `*`. The wildcard can represent any
# string of alphanumeric characters. For example, the pattern
# `'file_*.tif'` will match the files `'file_1.tif'`, `'file_2.tiv'`, or
# even `'file_qeoiurghtfoqaegbn34pf.tif'`… but it will not match
# `'something-else.csv'` or even `'something-else.tif'`.
#
# In this notebook, we’ll use the `.rglob()`, or **recursive** glob method
# of the Path object instead. It works similarly, but you’ll notice that
# we have to convert the results to a list with the `list()` function.
#
# > **GOTCHA ALERT!**
# >
# > `glob` doesn’t necessarily find files in the order you would expect.
# > Make sure to **sort** your file names like it says in the textbook.
#
# <link rel="stylesheet" type="text/css" href="./assets/styles.css"><div class="callout callout-style-default callout-titled callout-respond"><div class="callout-header"><div class="callout-icon-container"><i class="callout-icon"></i></div><div class="callout-title-container flex-fill">Reflect and Respond</div></div><div class="callout-body-container callout-body"><p>Take a look at the file names for the NDVI files. What do you notice
# is the same for all the files? Keep in mind that for this analysis you
# only want to import the NDVI files, not the Quality files (which would
# be used to identify potential incorrect measurements).</p></div></div>

# %% [markdown]
# YOUR ANSWER HERE

# %% [markdown]
# <link rel="stylesheet" type="text/css" href="./assets/styles.css"><div class="callout callout-style-default callout-titled callout-task"><div class="callout-header"><div class="callout-icon-container"><i class="callout-icon"></i></div><div class="callout-title-container flex-fill">Try It</div></div><div class="callout-body-container callout-body"><ol type="1">
# <li>Create a <strong>pattern</strong> for the files you want to import.
# Your pattern should include the parts of the file names that are the
# same for all files, and replace the rest with the <code>*</code>
# character. Make sure to match the NDVI files, but not the Quality
# files!</li>
# <li>Replace <code>ndvi-pattern</code> with your pattern</li>
# <li>Run the code and make sure that you are getting all the files you
# want and none of the files you don’t!</li>
# </ol></div></div>

# %%
# Get a sorted list of NDVI tif file paths
ndvi_paths = sorted(list(project.project_dir.rglob('*NDVI*.tif')))

# Display the first and last three files paths to check the pattern
ndvi_paths[:3], ndvi_paths[-3:]
# Out:
# ([PosixPath('/workspaces/data/tubarjal_dir/tubarjal-ndvi/MOD13Q1.061_2001137_to_2022244/MOD13Q1.061__250m_16_days_NDVI_doy2001145000000_aid0001.tif'),
#   PosixPath('/workspaces/data/tubarjal_dir/tubarjal-ndvi/MOD13Q1.061_2001137_to_2022244/MOD13Q1.061__250m_16_days_NDVI_doy2001161000000_aid0001.tif'),
#   PosixPath('/workspaces/data/tubarjal_dir/tubarjal-ndvi/MOD13Q1.061_2001137_to_2022244/MOD13Q1.061__250m_16_days_NDVI_doy2001177000000_aid0001.tif')],
#  [PosixPath('/workspaces/data/tubarjal_dir/tubarjal-ndvi/MOD13Q1.061_2001137_to_2022244/MOD13Q1.061__250m_16_days_NDVI_doy2022209000000_aid0001.tif'),
#   PosixPath('/workspaces/data/tubarjal_dir/tubarjal-ndvi/MOD13Q1.061_2001137_to_2022244/MOD13Q1.061__250m_16_days_NDVI_doy2022225000000_aid0001.tif'),
#   PosixPath('/workspaces/data/tubarjal_dir/tubarjal-ndvi/MOD13Q1.061_2001137_to_2022244/MOD13Q1.061__250m_16_days_NDVI_doy2022241000000_aid0001.tif')])

# %% [markdown]
# ## Repeating tasks in Python
#
# Now you should have a few dozen files! For each file, you need to:
#
# -   Load the file in using the `rioxarray` library
# -   Get the date from the file name
# -   Add the date as a dimension coordinate
# -   Give your data variable a name
#
# You don’t want to write out the code for each file! That’s a recipe for
# copy pasta. Luckily, Python has tools for doing similar tasks
# repeatedly. In this case, you’ll use one called a `for` loop.
#
# There’s some code below that uses a `for` loop in what is called an
# **accumulation pattern** to process each file. That means that you will
# save the results of your processing to a list each time you process the
# files, and then merge all the arrays in the list.
#
# <link rel="stylesheet" type="text/css" href="./assets/styles.css"><div class="callout callout-style-default callout-titled callout-task"><div class="callout-header"><div class="callout-icon-container"><i class="callout-icon"></i></div><div class="callout-title-container flex-fill">Try It</div></div><div class="callout-body-container callout-body"><ul>
# <li>Look at the file names. How many characters from the end is the
# date? <code>doy_start</code> and <code>doy_end</code> are used to
# extract the day of the year (doy) from the file name. You will need to
# count characters from the end and change the values to get the right
# part of the file name. HINT: the index -1 in Python means the last
# value, -2 second-to-last, and so on.</li>
# <li>Replace any required variable names with your chosen variable
# names</li>
# </ul></div></div>

# %%
doy_start = -25
doy_end = -19

# Loop through each NDVI image
ndvi_das = []
for ndvi_path in ndvi_paths:
    # Get date from the file name
    doy = ndvi_path.name[doy_start:doy_end]
    date = pd.to_datetime(doy, format='%Y%j')

    # Open dataset
    da = rxr.open_rasterio(ndvi_path, mask_and_scale=True).squeeze()

    # Add date dimension and clean up metadata
    da = da.assign_coords({'date': date})
    da = da.expand_dims({'date': 1})
    da.name = 'NDVI'

    # Prepare for concatenation
    ndvi_das.append(da)

len(ndvi_das)
# Out:
# 154

# %%
ndvi_das
# Out:
# [<xarray.DataArray 'NDVI' (date: 1, y: 85, x: 165)> Size: 56kB
#  array([[[0.1362    , 0.1365    , 0.1354    , ..., 0.1091    ,
#           0.1739    , 0.4689    ],
#          [0.1348    , 0.1345    , 0.1345    , ..., 0.2244    ,
#           0.2244    , 0.3102    ],
#          [0.1311    , 0.129     , 0.1285    , ..., 0.27199998,
#           0.2547    , 0.1899    ],
#          ...,
#          [0.12459999, 0.12799999, 0.12799999, ..., 0.1252    ,
#           0.12469999, 0.1604    ],
#          [0.1309    , 0.13059999, 0.13149999, ..., 0.12329999,
#           0.14919999, 0.2383    ],
#          [0.1282    , 0.1309    , 0.1309    , ..., 0.1078    ,
#           0.14389999, 0.1849    ]]], shape=(1, 85, 165), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 1kB 37.87 37.88 37.88 37.88 ... 38.21 38.21 38.22
#    * y            (y) float64 680B 30.33 30.33 30.33 30.33 ... 30.16 30.16 30.16
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2001-01-14
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 85, x: 165)> Size: 56kB
#  array([[[0.13159999, 0.1305    , 0.1327    , ..., 0.1186    ,
#           0.3356    , 0.2803    ],
#          [0.1278    , 0.1269    , 0.1269    , ..., 0.35279998,
#           0.35279998, 0.2351    ],
#          [0.1283    , 0.1269    , 0.129     , ..., 0.17559999,
#           0.2003    , 0.1674    ],
#          ...,
#          [0.13409999, 0.1261    , 0.1261    , ..., 0.1125    ,
#           0.11189999, 0.14039999],
#          [0.12329999, 0.12379999, 0.12539999, ..., 0.1125    ,
#           0.10969999, 0.1422    ],
#          [0.12619999, 0.1294    , 0.1328    , ..., 0.1089    ,
#           0.12719999, 0.1784    ]]], shape=(1, 85, 165), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 1kB 37.87 37.88 37.88 37.88 ... 38.21 38.21 38.22
#    * y            (y) float64 680B 30.33 30.33 30.33 30.33 ... 30.16 30.16 30.16
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2001-01-16
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 85, x: 165)> Size: 56kB
#  array([[[0.1382    , 0.1347    , 0.1321    , ..., 0.11979999,
#           0.2571    , 0.25869998],
#          [0.1347    , 0.13419999, 0.13419999, ..., 0.1962    ,
#           0.1962    , 0.19829999],
#          [0.1264    , 0.13059999, 0.1282    , ..., 0.15779999,
#           0.16149999, 0.1401    ],
#          ...,
#          [0.1384    , 0.1346    , 0.1346    , ..., 0.1007    ,
#           0.1007    , 0.1091    ],
#          [0.13509999, 0.1346    , 0.1347    , ..., 0.1033    ,
#           0.1007    , 0.1153    ],
#          [0.13509999, 0.13329999, 0.1336    , ..., 0.1045    ,
#           0.1059    , 0.14739999]]], shape=(1, 85, 165), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 1kB 37.87 37.88 37.88 37.88 ... 38.21 38.21 38.22
#    * y            (y) float64 680B 30.33 30.33 30.33 30.33 ... 30.16 30.16 30.16
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2001-01-17
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 85, x: 165)> Size: 56kB
#  array([[[0.13229999, 0.13409999, 0.1336    , ..., 0.1171    ,
#           0.2341    , 0.4763    ],
#          [0.1314    , 0.1304    , 0.1304    , ..., 0.2341    ,
#           0.2341    , 0.4763    ],
#          [0.12889999, 0.1293    , 0.1296    , ..., 0.1716    ,
#           0.2039    , 0.1688    ],
#          ...,
#          [0.1304    , 0.13      , 0.13      , ..., 0.118     ,
#           0.1217    , 0.1261    ],
#          [0.1322    , 0.1285    , 0.1296    , ..., 0.11979999,
#           0.11979999, 0.1502    ],
#          [0.131     , 0.1285    , 0.12799999, ..., 0.1077    ,
#           0.1343    , 0.1502    ]]], shape=(1, 85, 165), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 1kB 37.87 37.88 37.88 37.88 ... 38.21 38.21 38.22
#    * y            (y) float64 680B 30.33 30.33 30.33 30.33 ... 30.16 30.16 30.16
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2001-01-19
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 85, x: 165)> Size: 56kB
#  array([[[0.1336    , 0.1361    , 0.133     , ..., 0.11669999,
#           0.2732    , 0.3831    ],
#          [0.1321    , 0.1295    , 0.1295    , ..., 0.1874    ,
#           0.1874    , 0.1874    ],
#          [0.1285    , 0.1294    , 0.1286    , ..., 0.1585    ,
#           0.1679    , 0.2376    ],
#          ...,
#          [0.1308    , 0.1328    , 0.1328    , ..., 0.12329999,
#           0.1195    , 0.1215    ],
#          [0.1322    , 0.13059999, 0.13509999, ..., 0.117     ,
#           0.127     , 0.16049999],
#          [0.12719999, 0.1313    , 0.1313    , ..., 0.1188    ,
#           0.1496    , 0.1496    ]]], shape=(1, 85, 165), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 1kB 37.87 37.88 37.88 37.88 ... 38.21 38.21 38.22
#    * y            (y) float64 680B 30.33 30.33 30.33 30.33 ... 30.16 30.16 30.16
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2001-01-20
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 85, x: 165)> Size: 56kB
#  array([[[0.1319    , 0.13329999, 0.1354    , ..., 0.1201    ,
#           0.197     , 0.32259998],
#          [0.1278    , 0.1354    , 0.1354    , ..., 0.1609    ,
#           0.1609    , 0.1929    ],
#          [0.1314    , 0.12979999, 0.1281    , ..., 0.16309999,
#           0.1678    , 0.13939999],
#          ...,
#          [0.1352    , 0.1327    , 0.1327    , ..., 0.1175    ,
#           0.11589999, 0.1236    ],
#          [0.127     , 0.13059999, 0.1372    , ..., 0.11589999,
#           0.1129    , 0.1329    ],
#          [0.1329    , 0.1356    , 0.1317    , ..., 0.0998    ,
#           0.0998    , 0.1292    ]]], shape=(1, 85, 165), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 1kB 37.87 37.88 37.88 37.88 ... 38.21 38.21 38.22
#    * y            (y) float64 680B 30.33 30.33 30.33 30.33 ... 30.16 30.16 30.16
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2001-01-22
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 85, x: 165)> Size: 56kB
#  array([[[0.13149999, 0.1349    , 0.1349    , ..., 0.1144    ,
#           0.2444    , 0.4897    ],
#          [0.13069999, 0.13069999, 0.13069999, ..., 0.18249999,
#           0.18249999, 0.4604    ],
#          [0.12799999, 0.1275    , 0.1291    , ..., 0.17019999,
#           0.18249999, 0.2013    ],
#          ...,
#          [0.1294    , 0.1283    , 0.1283    , ..., 0.1116    ,
#           0.1098    , 0.12159999],
#          [0.1294    , 0.12709999, 0.12979999, ..., 0.1085    ,
#           0.1304    , 0.12159999],
#          [0.1252    , 0.1259    , 0.12719999, ..., 0.11      ,
#           0.1434    , 0.1595    ]]], shape=(1, 85, 165), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 1kB 37.87 37.88 37.88 37.88 ... 38.21 38.21 38.22
#    * y            (y) float64 680B 30.33 30.33 30.33 30.33 ... 30.16 30.16 30.16
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2001-01-24
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 85, x: 165)> Size: 56kB
#  array([[[0.13949999, 0.13949999, 0.1391    , ..., 0.1208    ,
#           0.2747    , 0.4493    ],
#          [0.1398    , 0.141     , 0.141     , ..., 0.20289999,
#           0.20289999, 0.258     ],
#          [0.1371    , 0.1384    , 0.1396    , ..., 0.20789999,
#           0.2568    , 0.1951    ],
#          ...,
#          [0.13599999, 0.13599999, 0.13599999, ..., 0.1762    ,
#           0.1313    , 0.1753    ],
#          [0.1381    , 0.1305    , 0.1318    , ..., 0.20179999,
#           0.1563    , 0.2798    ],
#          [0.1301    , 0.1287    , 0.1346    , ..., 0.1909    ,
#           0.16569999, 0.2562    ]]], shape=(1, 85, 165), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 1kB 37.87 37.88 37.88 37.88 ... 38.21 38.21 38.22
#    * y            (y) float64 680B 30.33 30.33 30.33 30.33 ... 30.16 30.16 30.16
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2002-01-14
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 85, x: 165)> Size: 56kB
#  array([[[0.13159999, 0.1329    , 0.13149999, ..., 0.1204    ,
#           0.1979    , 0.4179    ],
#          [0.1314    , 0.1292    , 0.1292    , ..., 0.17119999,
#           0.17119999, 0.41169998],
#          [0.1375    , 0.13769999, 0.13769999, ..., 0.16589999,
#           0.1803    , 0.1803    ],
#          ...,
#          [0.1349    , 0.13409999, 0.13409999, ..., 0.1365    ,
#           0.1293    , 0.1726    ],
#          [0.1378    , 0.1304    , 0.13149999, ..., 0.1584    ,
#           0.1584    , 0.1356    ],
#          [0.1299    , 0.1294    , 0.1292    , ..., 0.1758    ,
#           0.1583    , 0.1783    ]]], shape=(1, 85, 165), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 1kB 37.87 37.88 37.88 37.88 ... 38.21 38.21 38.22
#    * y            (y) float64 680B 30.33 30.33 30.33 30.33 ... 30.16 30.16 30.16
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2002-01-16
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 85, x: 165)> Size: 56kB
#  array([[[0.1381    , 0.1311    , 0.1309    , ..., 0.1208    ,
#           0.34019998, 0.5535    ],
#          [0.1388    , 0.1384    , 0.1384    , ..., 0.2918    ,
#           0.2918    , 0.32909998],
#          [0.1352    , 0.13849999, 0.14039999, ..., 0.1472    ,
#           0.148     , 0.2324    ],
#          ...,
#          [0.137     , 0.13499999, 0.13499999, ..., 0.1457    ,
#           0.1285    , 0.1453    ],
#          [0.1349    , 0.1296    , 0.1321    , ..., 0.1662    ,
#           0.145     , 0.1453    ],
#          [0.1237    , 0.1303    , 0.1347    , ..., 0.16569999,
#           0.1618    , 0.19399999]]], shape=(1, 85, 165), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 1kB 37.87 37.88 37.88 37.88 ... 38.21 38.21 38.22
#    * y            (y) float64 680B 30.33 30.33 30.33 30.33 ... 30.16 30.16 30.16
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2002-01-17
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 85, x: 165)> Size: 56kB
#  array([[[0.1309    , 0.1309    , 0.1317    , ..., 0.1302    ,
#           0.46539998, 0.5812    ],
#          [0.13329999, 0.13499999, 0.13499999, ..., 0.2931    ,
#           0.2931    , 0.50589997],
#          [0.1312    , 0.134     , 0.1379    , ..., 0.1408    ,
#           0.1558    , 0.1908    ],
#          ...,
#          [0.13229999, 0.13859999, 0.13859999, ..., 0.1275    ,
#           0.1275    , 0.1434    ],
#          [0.13319999, 0.13069999, 0.1311    , ..., 0.16759999,
#           0.1275    , 0.1399    ],
#          [0.1267    , 0.1274    , 0.12979999, ..., 0.1664    ,
#           0.1451    , 0.1715    ]]], shape=(1, 85, 165), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 1kB 37.87 37.88 37.88 37.88 ... 38.21 38.21 38.22
#    * y            (y) float64 680B 30.33 30.33 30.33 30.33 ... 30.16 30.16 30.16
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2002-01-19
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 85, x: 165)> Size: 56kB
#  array([[[0.1361    , 0.13759999, 0.1346    , ..., 0.1228    ,
#           0.43359998, 0.43359998],
#          [0.1374    , 0.1371    , 0.1371    , ..., 0.13149999,
#           0.13149999, 0.2395    ],
#          [0.1384    , 0.1354    , 0.1365    , ..., 0.131     ,
#           0.1401    , 0.1916    ],
#          ...,
#          [0.1347    , 0.1327    , 0.1327    , ..., 0.1427    ,
#           0.125     , 0.1264    ],
#          [0.13159999, 0.133     , 0.1302    , ..., 0.1577    ,
#           0.1428    , 0.1264    ],
#          [0.12799999, 0.1284    , 0.1304    , ..., 0.15799999,
#           0.1436    , 0.16      ]]], shape=(1, 85, 165), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 1kB 37.87 37.88 37.88 37.88 ... 38.21 38.21 38.22
#    * y            (y) float64 680B 30.33 30.33 30.33 30.33 ... 30.16 30.16 30.16
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2002-01-20
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 85, x: 165)> Size: 56kB
#  array([[[0.13059999, 0.1309    , 0.13069999, ..., 0.14209999,
#           0.14209999, 0.65959996],
#          [0.1308    , 0.12979999, 0.12979999, ..., 0.12979999,
#           0.12979999, 0.32619998],
#          [0.1347    , 0.13069999, 0.1303    , ..., 0.1325    ,
#           0.1373    , 0.1197    ],
#          ...,
#          [0.13239999, 0.13329999, 0.13329999, ..., 0.1521    ,
#           0.1201    , 0.1356    ],
#          [0.13149999, 0.1278    , 0.1285    , ..., 0.163     ,
#           0.1396    , 0.1258    ],
#          [0.12629999, 0.1273    , 0.1293    , ..., 0.1598    ,
#           0.15089999, 0.1787    ]]], shape=(1, 85, 165), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 1kB 37.87 37.88 37.88 37.88 ... 38.21 38.21 38.22
#    * y            (y) float64 680B 30.33 30.33 30.33 30.33 ... 30.16 30.16 30.16
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2002-01-22
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 85, x: 165)> Size: 56kB
#  array([[[0.1363    , 0.1363    , 0.1353    , ..., 0.11849999,
#           0.42819998, 0.6119    ],
#          [0.1353    , 0.1353    , 0.1353    , ..., 0.2294    ,
#           0.2294    , 0.45389998],
#          [0.13509999, 0.13589999, 0.137     , ..., 0.1354    ,
#           0.1374    , 0.20619999],
#          ...,
#          [0.133     , 0.1291    , 0.1291    , ..., 0.1479    ,
#           0.1226    , 0.13499999],
#          [0.133     , 0.1287    , 0.13499999, ..., 0.1643    ,
#           0.14729999, 0.17019999],
#          [0.1291    , 0.1354    , 0.1303    , ..., 0.1619    ,
#           0.1655    , 0.17459999]]], shape=(1, 85, 165), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 1kB 37.87 37.88 37.88 37.88 ... 38.21 38.21 38.22
#    * y            (y) float64 680B 30.33 30.33 30.33 30.33 ... 30.16 30.16 30.16
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2002-01-24
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 85, x: 165)> Size: 56kB
#  array([[[0.137     , 0.1354    , 0.134     , ..., 0.1317    ,
#           0.33969998, 0.4306    ],
#          [0.1356    , 0.1371    , 0.1371    , ..., 0.1486    ,
#           0.1486    , 0.29369998],
#          [0.13239999, 0.1343    , 0.1356    , ..., 0.16059999,
#           0.1704    , 0.1591    ],
#          ...,
#          [0.1328    , 0.1325    , 0.1325    , ..., 0.1388    ,
#           0.123     , 0.1945    ],
#          [0.1325    , 0.13      , 0.13329999, ..., 0.14649999,
#           0.1347    , 0.19299999],
#          [0.1276    , 0.1276    , 0.13069999, ..., 0.1462    ,
#           0.1585    , 0.2184    ]]], shape=(1, 85, 165), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 1kB 37.87 37.88 37.88 37.88 ... 38.21 38.21 38.22
#    * y            (y) float64 680B 30.33 30.33 30.33 30.33 ... 30.16 30.16 30.16
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2003-01-14
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 85, x: 165)> Size: 56kB
#  array([[[0.1415    , 0.1407    , 0.13329999, ..., 0.13229999,
#           0.1647    , 0.24689999],
#          [0.1313    , 0.1407    , 0.1407    , ..., 0.15339999,
#           0.15339999, 0.2119    ],
#          [0.1451    , 0.1366    , 0.1362    , ..., 0.161     ,
#           0.153     , 0.14649999],
#          ...,
#          [0.1319    , 0.134     , 0.134     , ..., 0.1265    ,
#           0.137     , 0.1743    ],
#          [0.1328    , 0.1328    , 0.134     , ..., 0.13599999,
#           0.13149999, 0.1815    ],
#          [0.133     , 0.1328    , 0.13319999, ..., 0.14379999,
#           0.1586    , 0.1959    ]]], shape=(1, 85, 165), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 1kB 37.87 37.88 37.88 37.88 ... 38.21 38.21 38.22
#    * y            (y) float64 680B 30.33 30.33 30.33 30.33 ... 30.16 30.16 30.16
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2003-01-16
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 85, x: 165)> Size: 56kB
#  array([[[0.1337    , 0.1354    , 0.1322    , ..., 0.12069999,
#           0.153     , 0.2263    ],
#          [0.13229999, 0.13319999, 0.13319999, ..., 0.1461    ,
#           0.1461    , 0.19849999],
#          [0.1301    , 0.1352    , 0.13239999, ..., 0.15079999,
#           0.1431    , 0.1431    ],
#          ...,
#          [0.1349    , 0.1321    , 0.1321    , ..., 0.1244    ,
#           0.13159999, 0.1565    ],
#          [0.1346    , 0.12969999, 0.13069999, ..., 0.134     ,
#           0.134     , 0.15179999],
#          [0.1312    , 0.1327    , 0.12969999, ..., 0.1431    ,
#           0.1362    , 0.16759999]]], shape=(1, 85, 165), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 1kB 37.87 37.88 37.88 37.88 ... 38.21 38.21 38.22
#    * y            (y) float64 680B 30.33 30.33 30.33 30.33 ... 30.16 30.16 30.16
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2003-01-17
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 85, x: 165)> Size: 56kB
#  array([[[0.1362    , 0.13759999, 0.13759999, ..., 0.1226    ,
#           0.1867    , 0.1919    ],
#          [0.1373    , 0.1355    , 0.1355    , ..., 0.1314    ,
#           0.1314    , 0.1643    ],
#          [0.1363    , 0.1378    , 0.14119999, ..., 0.13949999,
#           0.14459999, 0.1241    ],
#          ...,
#          [0.13419999, 0.13419999, 0.13419999, ..., 0.1275    ,
#           0.118     , 0.1331    ],
#          [0.1304    , 0.13419999, 0.1311    , ..., 0.1424    ,
#           0.12289999, 0.1497    ],
#          [0.1278    , 0.1313    , 0.13229999, ..., 0.1425    ,
#           0.14389999, 0.1721    ]]], shape=(1, 85, 165), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 1kB 37.87 37.88 37.88 37.88 ... 38.21 38.21 38.22
#    * y            (y) float64 680B 30.33 30.33 30.33 30.33 ... 30.16 30.16 30.16
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2003-01-19
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 85, x: 165)> Size: 56kB
#  array([[[0.1296    , 0.14039999, 0.1347    , ..., 0.1138    ,
#           0.1444    , 0.1889    ],
#          [0.1303    , 0.1303    , 0.1303    , ..., 0.1406    ,
#           0.1406    , 0.1656    ],
#          [0.1335    , 0.1343    , 0.1328    , ..., 0.1401    ,
#           0.1401    , 0.13239999],
#          ...,
#          [0.1325    , 0.1309    , 0.1309    , ..., 0.1226    ,
#           0.1177    , 0.13949999],
#          [0.1291    , 0.1281    , 0.1302    , ..., 0.14      ,
#           0.1251    , 0.13669999],
#          [0.1274    , 0.1309    , 0.1281    , ..., 0.14      ,
#           0.1311    , 0.1417    ]]], shape=(1, 85, 165), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 1kB 37.87 37.88 37.88 37.88 ... 38.21 38.21 38.22
#    * y            (y) float64 680B 30.33 30.33 30.33 30.33 ... 30.16 30.16 30.16
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2003-01-20
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 85, x: 165)> Size: 56kB
#  array([[[0.1373    , 0.1378    , 0.1361    , ..., 0.1158    ,
#           0.1461    , 0.1581    ],
#          [0.1327    , 0.1344    , 0.1344    , ..., 0.13319999,
#           0.13319999, 0.1521    ],
#          [0.1387    , 0.1357    , 0.1348    , ..., 0.14039999,
#           0.1406    , 0.1255    ],
#          ...,
#          [0.13669999, 0.1309    , 0.1309    , ..., 0.14019999,
#           0.1162    , 0.12459999],
#          [0.1243    , 0.1243    , 0.1304    , ..., 0.1415    ,
#           0.1252    , 0.1276    ],
#          [0.13239999, 0.1293    , 0.1314    , ..., 0.1422    ,
#           0.1308    , 0.1383    ]]], shape=(1, 85, 165), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 1kB 37.87 37.88 37.88 37.88 ... 38.21 38.21 38.22
#    * y            (y) float64 680B 30.33 30.33 30.33 30.33 ... 30.16 30.16 30.16
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2003-01-22
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 85, x: 165)> Size: 56kB
#  array([[[0.13509999, 0.1346    , 0.133     , ..., 0.1209    ,
#           0.1461    , 0.1481    ],
#          [0.132     , 0.132     , 0.132     , ..., 0.1237    ,
#           0.1237    , 0.14029999],
#          [0.12979999, 0.134     , 0.1344    , ..., 0.1318    ,
#           0.1443    , 0.14029999],
#          ...,
#          [0.1327    , 0.1292    , 0.1292    , ..., 0.1264    ,
#           0.1171    , 0.1183    ],
#          [0.1327    , 0.1274    , 0.1269    , ..., 0.1378    ,
#           0.12329999, 0.131     ],
#          [0.1275    , 0.12619999, 0.1266    , ..., 0.1372    ,
#           0.129     , 0.1384    ]]], shape=(1, 85, 165), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 1kB 37.87 37.88 37.88 37.88 ... 38.21 38.21 38.22
#    * y            (y) float64 680B 30.33 30.33 30.33 30.33 ... 30.16 30.16 30.16
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2003-01-24
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 85, x: 165)> Size: 56kB
#  array([[[0.14109999, 0.14289999, 0.1428    , ..., 0.119     ,
#           0.1582    , 0.1689    ],
#          [0.1441    , 0.1441    , 0.1441    , ..., 0.2105    ,
#           0.2105    , 0.2105    ],
#          [0.1358    , 0.1408    , 0.1391    , ..., 0.27629998,
#           0.27629998, 0.1768    ],
#          ...,
#          [0.1304    , 0.1296    , 0.1296    , ..., 0.19929999,
#           0.13589999, 0.1585    ],
#          [0.1304    , 0.1293    , 0.1293    , ..., 0.23629999,
#           0.1626    , 0.124     ],
#          [0.1294    , 0.1304    , 0.1301    , ..., 0.2461    ,
#           0.176     , 0.12629999]]], shape=(1, 85, 165), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 1kB 37.87 37.88 37.88 37.88 ... 38.21 38.21 38.22
#    * y            (y) float64 680B 30.33 30.33 30.33 30.33 ... 30.16 30.16 30.16
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2004-01-14
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 85, x: 165)> Size: 56kB
#  array([[[0.13419999, 0.1362    , 0.1337    , ..., 0.1299    ,
#           0.1338    , 0.1647    ],
#          [0.1356    , 0.13499999, 0.13499999, ..., 0.16309999,
#           0.16309999, 0.16309999],
#          [0.1364    , 0.1363    , 0.1353    , ..., 0.17799999,
#           0.1989    , 0.148     ],
#          ...,
#          [0.1266    , 0.1265    , 0.1265    , ..., 0.17639999,
#           0.1223    , 0.162     ],
#          [0.1282    , 0.1268    , 0.1336    , ..., 0.19399999,
#           0.129     , 0.116     ],
#          [0.1285    , 0.1296    , 0.1339    , ..., 0.19669999,
#           0.1784    , 0.1178    ]]], shape=(1, 85, 165), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 1kB 37.87 37.88 37.88 37.88 ... 38.21 38.21 38.22
#    * y            (y) float64 680B 30.33 30.33 30.33 30.33 ... 30.16 30.16 30.16
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2004-01-16
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 85, x: 165)> Size: 56kB
#  array([[[0.14109999, 0.1384    , 0.1379    , ..., 0.11629999,
#           0.1296    , 0.12249999],
#          [0.1318    , 0.1361    , 0.1361    , ..., 0.1961    ,
#           0.1961    , 0.1847    ],
#          [0.1357    , 0.1357    , 0.13759999, ..., 0.18439999,
#           0.18439999, 0.1513    ],
#          ...,
#          [0.1301    , 0.12879999, 0.12879999, ..., 0.14019999,
#           0.119     , 0.1213    ],
#          [0.1355    , 0.1287    , 0.1317    , ..., 0.17289999,
#           0.1339    , 0.1103    ],
#          [0.13239999, 0.1319    , 0.1378    , ..., 0.1832    ,
#           0.1339    , 0.1113    ]]], shape=(1, 85, 165), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 1kB 37.87 37.88 37.88 37.88 ... 38.21 38.21 38.22
#    * y            (y) float64 680B 30.33 30.33 30.33 30.33 ... 30.16 30.16 30.16
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2004-01-17
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 85, x: 165)> Size: 56kB
#  array([[[0.14119999, 0.14029999, 0.1401    , ..., 0.1191    ,
#           0.1243    , 0.1239    ],
#          [0.14199999, 0.1417    , 0.1417    , ..., 0.1714    ,
#           0.1714    , 0.13329999],
#          [0.1434    , 0.1434    , 0.1444    , ..., 0.16929999,
#           0.1591    , 0.1209    ],
#          ...,
#          [0.1261    , 0.12799999, 0.12799999, ..., 0.1255    ,
#           0.1255    , 0.1317    ],
#          [0.1312    , 0.1292    , 0.1325    , ..., 0.12619999,
#           0.12619999, 0.1143    ],
#          [0.1327    , 0.1294    , 0.1294    , ..., 0.1232    ,
#           0.1146    , 0.1191    ]]], shape=(1, 85, 165), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 1kB 37.87 37.88 37.88 37.88 ... 38.21 38.21 38.22
#    * y            (y) float64 680B 30.33 30.33 30.33 30.33 ... 30.16 30.16 30.16
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2004-01-19
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 85, x: 165)> Size: 56kB
#  array([[[0.1365    , 0.13669999, 0.1364    , ..., 0.11409999,
#           0.12069999, 0.1168    ],
#          [0.1362    , 0.1363    , 0.1363    , ..., 0.17279999,
#           0.17279999, 0.1408    ],
#          [0.138     , 0.139     , 0.138     , ..., 0.1876    ,
#           0.17369999, 0.1616    ],
#          ...,
#          [0.127     , 0.12879999, 0.12879999, ..., 0.1165    ,
#           0.1124    , 0.1416    ],
#          [0.12879999, 0.1296    , 0.1296    , ..., 0.12249999,
#           0.12249999, 0.1067    ],
#          [0.12969999, 0.12969999, 0.13      , ..., 0.13229999,
#           0.12459999, 0.11449999]]], shape=(1, 85, 165), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 1kB 37.87 37.88 37.88 37.88 ... 38.21 38.21 38.22
#    * y            (y) float64 680B 30.33 30.33 30.33 30.33 ... 30.16 30.16 30.16
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2004-01-20
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 85, x: 165)> Size: 56kB
#  array([[[0.14209999, 0.14209999, 0.1426    , ..., 0.1212    ,
#           0.1205    , 0.12019999],
#          [0.1331    , 0.13769999, 0.13769999, ..., 0.147     ,
#           0.147     , 0.147     ],
#          [0.1462    , 0.1424    , 0.1369    , ..., 0.16589999,
#           0.1752    , 0.1336    ],
#          ...,
#          [0.1308    , 0.12799999, 0.12799999, ..., 0.124     ,
#           0.1095    , 0.1363    ],
#          [0.1292    , 0.1277    , 0.1301    , ..., 0.11369999,
#           0.1037    , 0.10439999],
#          [0.1313    , 0.13      , 0.1299    , ..., 0.1239    ,
#           0.1239    , 0.1092    ]]], shape=(1, 85, 165), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 1kB 37.87 37.88 37.88 37.88 ... 38.21 38.21 38.22
#    * y            (y) float64 680B 30.33 30.33 30.33 30.33 ... 30.16 30.16 30.16
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2004-01-22
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 85, x: 165)> Size: 56kB
#  array([[[0.13239999, 0.13229999, 0.1309    , ..., 0.12069999,
#           0.12469999, 0.1241    ],
#          [0.1304    , 0.1282    , 0.1282    , ..., 0.15789999,
#           0.15789999, 0.15789999],
#          [0.1339    , 0.1355    , 0.13669999, ..., 0.16229999,
#           0.16669999, 0.13509999],
#          ...,
#          [0.1264    , 0.133     , 0.133     , ..., 0.12029999,
#           0.1144    , 0.1467    ],
#          [0.1245    , 0.1313    , 0.1313    , ..., 0.1183    ,
#           0.1183    , 0.1157    ],
#          [0.1274    , 0.13409999, 0.13329999, ..., 0.1206    ,
#           0.1122    , 0.1156    ]]], shape=(1, 85, 165), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 1kB 37.87 37.88 37.88 37.88 ... 38.21 38.21 38.22
#    * y            (y) float64 680B 30.33 30.33 30.33 30.33 ... 30.16 30.16 30.16
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2004-01-24
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 85, x: 165)> Size: 56kB
#  array([[[0.1346    , 0.1346    , 0.1346    , ..., 0.1261    ,
#           0.13159999, 0.139     ],
#          [0.1338    , 0.1361    , 0.1361    , ..., 0.2278    ,
#           0.2278    , 0.139     ],
#          [0.12969999, 0.1339    , 0.1335    , ..., 0.2278    ,
#           0.24069999, 0.1466    ],
#          ...,
#          [0.1277    , 0.12889999, 0.12889999, ..., 0.1584    ,
#           0.12969999, 0.11589999],
#          [0.1299    , 0.11629999, 0.1251    , ..., 0.22729999,
#           0.166     , 0.1142    ],
#          [0.1175    , 0.1217    , 0.1296    , ..., 0.21069999,
#           0.1584    , 0.1102    ]]], shape=(1, 85, 165), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 1kB 37.87 37.88 37.88 37.88 ... 38.21 38.21 38.22
#    * y            (y) float64 680B 30.33 30.33 30.33 30.33 ... 30.16 30.16 30.16
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2005-01-14
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 85, x: 165)> Size: 56kB
#  array([[[0.1282    , 0.1286    , 0.129     , ..., 0.1166    ,
#           0.15429999, 0.2986    ],
#          [0.13059999, 0.1301    , 0.1301    , ..., 0.18879999,
#           0.18879999, 0.2737    ],
#          [0.1296    , 0.1293    , 0.1295    , ..., 0.18879999,
#           0.189     , 0.1435    ],
#          ...,
#          [0.12379999, 0.1248    , 0.1248    , ..., 0.1415    ,
#           0.1117    , 0.1116    ],
#          [0.124     , 0.12      , 0.12529999, ..., 0.159     ,
#           0.1493    , 0.1068    ],
#          [0.1171    , 0.121     , 0.121     , ..., 0.1618    ,
#           0.1435    , 0.1068    ]]], shape=(1, 85, 165), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 1kB 37.87 37.88 37.88 37.88 ... 38.21 38.21 38.22
#    * y            (y) float64 680B 30.33 30.33 30.33 30.33 ... 30.16 30.16 30.16
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2005-01-16
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 85, x: 165)> Size: 56kB
#  array([[[0.137     , 0.1382    , 0.1393    , ..., 0.1184    ,
#           0.2883    , 0.5323    ],
#          [0.1346    , 0.1375    , 0.1375    , ..., 0.19649999,
#           0.19649999, 0.27809998],
#          [0.1337    , 0.1387    , 0.14119999, ..., 0.1926    ,
#           0.1602    , 0.1602    ],
#          ...,
#          [0.1301    , 0.1301    , 0.1301    , ..., 0.1248    ,
#           0.1063    , 0.106     ],
#          [0.1282    , 0.12459999, 0.1286    , ..., 0.14559999,
#           0.14559999, 0.1048    ],
#          [0.11889999, 0.1286    , 0.1355    , ..., 0.1661    ,
#           0.1433    , 0.1078    ]]], shape=(1, 85, 165), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 1kB 37.87 37.88 37.88 37.88 ... 38.21 38.21 38.22
#    * y            (y) float64 680B 30.33 30.33 30.33 30.33 ... 30.16 30.16 30.16
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2005-01-17
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 85, x: 165)> Size: 56kB
#  array([[[0.1305    , 0.1313    , 0.1343    , ..., 0.1295    ,
#           0.47129998, 0.5017    ],
#          [0.1372    , 0.1355    , 0.1355    , ..., 0.14289999,
#           0.14289999, 0.2893    ],
#          [0.1343    , 0.1349    , 0.1372    , ..., 0.1652    ,
#           0.1721    , 0.132     ],
#          ...,
#          [0.1293    , 0.1268    , 0.1268    , ..., 0.11229999,
#           0.1148    , 0.1157    ],
#          [0.12539999, 0.1257    , 0.12289999, ..., 0.1149    ,
#           0.1149    , 0.11      ],
#          [0.1221    , 0.12109999, 0.1241    , ..., 0.1208    ,
#           0.1067    , 0.1072    ]]], shape=(1, 85, 165), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 1kB 37.87 37.88 37.88 37.88 ... 38.21 38.21 38.22
#    * y            (y) float64 680B 30.33 30.33 30.33 30.33 ... 30.16 30.16 30.16
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2005-01-19
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 85, x: 165)> Size: 56kB
#  array([[[0.1302    , 0.1304    , 0.1353    , ..., 0.1193    ,
#           0.14199999, 0.28219998],
#          [0.12709999, 0.1388    , 0.1388    , ..., 0.1637    ,
#           0.1637    , 0.1969    ],
#          [0.1328    , 0.13599999, 0.13599999, ..., 0.1854    ,
#           0.18349999, 0.11849999],
#          ...,
#          [0.1299    , 0.1295    , 0.1295    , ..., 0.09999999,
#           0.09999999, 0.1041    ],
#          [0.1239    , 0.1275    , 0.1257    , ..., 0.1063    ,
#           0.1032    , 0.1003    ],
#          [0.1239    , 0.12329999, 0.1258    , ..., 0.1209    ,
#           0.10879999, 0.1059    ]]], shape=(1, 85, 165), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 1kB 37.87 37.88 37.88 37.88 ... 38.21 38.21 38.22
#    * y            (y) float64 680B 30.33 30.33 30.33 30.33 ... 30.16 30.16 30.16
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2005-01-20
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 85, x: 165)> Size: 56kB
#  array([[[0.13149999, 0.1302    , 0.1325    , ..., 0.14299999,
#           0.25849998, 0.5391    ],
#          [0.1328    , 0.13409999, 0.13409999, ..., 0.1865    ,
#           0.1865    , 0.46829998],
#          [0.1304    , 0.1356    , 0.1356    , ..., 0.18079999,
#           0.1999    , 0.1999    ],
#          ...,
#          [0.1265    , 0.1277    , 0.1277    , ..., 0.1113    ,
#           0.1023    , 0.1082    ],
#          [0.1317    , 0.1237    , 0.1275    , ..., 0.11279999,
#           0.1001    , 0.1039    ],
#          [0.1235    , 0.1215    , 0.1256    , ..., 0.123     ,
#           0.11279999, 0.11059999]]], shape=(1, 85, 165), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 1kB 37.87 37.88 37.88 37.88 ... 38.21 38.21 38.22
#    * y            (y) float64 680B 30.33 30.33 30.33 30.33 ... 30.16 30.16 30.16
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2005-01-22
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 85, x: 165)> Size: 56kB
#  array([[[0.1329    , 0.13319999, 0.13319999, ..., 0.15339999,
#           0.2399    , 0.6326    ],
#          [0.13059999, 0.1292    , 0.1292    , ..., 0.1918    ,
#           0.1918    , 0.4648    ],
#          [0.1286    , 0.12879999, 0.13329999, ..., 0.1911    ,
#           0.189     , 0.20289999],
#          ...,
#          [0.1287    , 0.12419999, 0.12419999, ..., 0.108     ,
#           0.10089999, 0.1043    ],
#          [0.12789999, 0.12419999, 0.12419999, ..., 0.1143    ,
#           0.1112    , 0.1041    ],
#          [0.12239999, 0.1213    , 0.1235    , ..., 0.12969999,
#           0.1144    , 0.1144    ]]], shape=(1, 85, 165), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 1kB 37.87 37.88 37.88 37.88 ... 38.21 38.21 38.22
#    * y            (y) float64 680B 30.33 30.33 30.33 30.33 ... 30.16 30.16 30.16
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2005-01-24
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 85, x: 165)> Size: 56kB
#  array([[[0.1326    , 0.1337    , 0.1313    , ..., 0.12629999,
#           0.1752    , 0.1501    ],
#          [0.134     , 0.134     , 0.134     , ..., 0.4342    ,
#           0.4342    , 0.1853    ],
#          [0.13939999, 0.1428    , 0.1337    , ..., 0.4342    ,
#           0.4261    , 0.1704    ],
#          ...,
#          [0.1256    , 0.1259    , 0.1259    , ..., 0.1839    ,
#           0.15349999, 0.219     ],
#          [0.1234    , 0.1259    , 0.12719999, ..., 0.2048    ,
#           0.1671    , 0.1997    ],
#          [0.1275    , 0.1275    , 0.1274    , ..., 0.2048    ,
#           0.2014    , 0.21509999]]], shape=(1, 85, 165), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 1kB 37.87 37.88 37.88 37.88 ... 38.21 38.21 38.22
#    * y            (y) float64 680B 30.33 30.33 30.33 30.33 ... 30.16 30.16 30.16
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2006-01-14
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 85, x: 165)> Size: 56kB
#  array([[[0.1328    , 0.13239999, 0.1322    , ..., 0.1129    ,
#           0.1221    , 0.14469999],
#          [0.1389    , 0.1331    , 0.1331    , ..., 0.26119998,
#           0.26119998, 0.22289999],
#          [0.1407    , 0.13939999, 0.14209999, ..., 0.4195    ,
#           0.3182    , 0.27519998],
#          ...,
#          [0.1321    , 0.1322    , 0.1322    , ..., 0.16839999,
#           0.1872    , 0.4915    ],
#          [0.1284    , 0.1322    , 0.1309    , ..., 0.17189999,
#           0.1697    , 0.1875    ],
#          [0.1277    , 0.12719999, 0.1291    , ..., 0.1857    ,
#           0.1857    , 0.191     ]]], shape=(1, 85, 165), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 1kB 37.87 37.88 37.88 37.88 ... 38.21 38.21 38.22
#    * y            (y) float64 680B 30.33 30.33 30.33 30.33 ... 30.16 30.16 30.16
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2006-01-16
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 85, x: 165)> Size: 56kB
#  array([[[0.137     , 0.1371    , 0.13599999, ..., 0.124     ,
#           0.16239999, 0.1295    ],
#          [0.1374    , 0.13859999, 0.13859999, ..., 0.2787    ,
#           0.2787    , 0.2787    ],
#          [0.13329999, 0.1396    , 0.1388    , ..., 0.4878    ,
#           0.6038    , 0.24329999],
#          ...,
#          [0.1355    , 0.1344    , 0.1344    , ..., 0.1601    ,
#           0.12889999, 0.1581    ],
#          [0.13599999, 0.1268    , 0.13069999, ..., 0.17629999,
#           0.1595    , 0.17729999],
#          [0.13069999, 0.1291    , 0.13239999, ..., 0.17989999,
#           0.1699    , 0.1853    ]]], shape=(1, 85, 165), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 1kB 37.87 37.88 37.88 37.88 ... 38.21 38.21 38.22
#    * y            (y) float64 680B 30.33 30.33 30.33 30.33 ... 30.16 30.16 30.16
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2006-01-17
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 85, x: 165)> Size: 56kB
#  array([[[0.1432    , 0.13599999, 0.1363    , ..., 0.1231    ,
#           0.2235    , 0.1481    ],
#          [0.1354    , 0.1375    , 0.1375    , ..., 0.3636    ,
#           0.3636    , 0.3434    ],
#          [0.14379999, 0.1476    , 0.13679999, ..., 0.6109    ,
#           0.524     , 0.1524    ],
#          ...,
#          [0.1374    , 0.13419999, 0.13419999, ..., 0.1662    ,
#           0.1428    , 0.21689999],
#          [0.1314    , 0.13069999, 0.1317    , ..., 0.1786    ,
#           0.17359999, 0.17359999],
#          [0.1314    , 0.1312    , 0.13319999, ..., 0.17799999,
#           0.1769    , 0.17899999]]], shape=(1, 85, 165), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 1kB 37.87 37.88 37.88 37.88 ... 38.21 38.21 38.22
#    * y            (y) float64 680B 30.33 30.33 30.33 30.33 ... 30.16 30.16 30.16
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2006-01-19
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 85, x: 165)> Size: 56kB
#  array([[[0.1426    , 0.1384    , 0.1409    , ..., 0.1709    ,
#           0.129     , 0.13229999],
#          [0.1347    , 0.1347    , 0.1347    , ..., 0.3636    ,
#           0.3636    , 0.2969    ],
#          [0.1416    , 0.1361    , 0.1392    , ..., 0.738     ,
#           0.5254    , 0.5254    ],
#          ...,
#          [0.13769999, 0.12709999, 0.12709999, ..., 0.14999999,
#           0.1281    , 0.206     ],
#          [0.1264    , 0.13      , 0.133     , ..., 0.1794    ,
#           0.1595    , 0.1778    ],
#          [0.1331    , 0.13      , 0.13589999, ..., 0.1801    ,
#           0.17639999, 0.1831    ]]], shape=(1, 85, 165), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 1kB 37.87 37.88 37.88 37.88 ... 38.21 38.21 38.22
#    * y            (y) float64 680B 30.33 30.33 30.33 30.33 ... 30.16 30.16 30.16
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2006-01-20
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 85, x: 165)> Size: 56kB
#  array([[[0.1409    , 0.1375    , 0.1366    , ..., 0.12789999,
#           0.1497    , 0.1497    ],
#          [0.1361    , 0.1369    , 0.1369    , ..., 0.45549998,
#           0.45549998, 0.4919    ],
#          [0.14029999, 0.14119999, 0.1419    , ..., 0.606     ,
#           0.7362    , 0.3179    ],
#          ...,
#          [0.1318    , 0.1318    , 0.1318    , ..., 0.1361    ,
#           0.123     , 0.16399999],
#          [0.1294    , 0.1286    , 0.134     , ..., 0.15259999,
#           0.1497    , 0.17119999],
#          [0.127     , 0.12789999, 0.1348    , ..., 0.1502    ,
#           0.1548    , 0.17119999]]], shape=(1, 85, 165), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 1kB 37.87 37.88 37.88 37.88 ... 38.21 38.21 38.22
#    * y            (y) float64 680B 30.33 30.33 30.33 30.33 ... 30.16 30.16 30.16
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2006-01-22
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 85, x: 165)> Size: 56kB
#  array([[[0.1426    , 0.1418    , 0.1418    , ..., 0.134     ,
#           0.13409999, 0.1407    ],
#          [0.14109999, 0.139     , 0.139     , ..., 0.29659998,
#           0.29659998, 0.243     ],
#          [0.1409    , 0.14019999, 0.14199999, ..., 0.5511    ,
#           0.68939996, 0.28219998],
#          ...,
#          [0.1354    , 0.12979999, 0.12979999, ..., 0.1214    ,
#           0.1494    , 0.3848    ],
#          [0.1276    , 0.12789999, 0.13229999, ..., 0.1243    ,
#           0.12789999, 0.1278    ],
#          [0.1269    , 0.1325    , 0.132     , ..., 0.1241    ,
#           0.1241    , 0.12789999]]], shape=(1, 85, 165), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 1kB 37.87 37.88 37.88 37.88 ... 38.21 38.21 38.22
#    * y            (y) float64 680B 30.33 30.33 30.33 30.33 ... 30.16 30.16 30.16
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2006-01-24
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 85, x: 165)> Size: 56kB
#  array([[[0.1435    , 0.1363    , 0.1363    , ..., 0.1428    ,
#           0.1463    , 0.2488    ],
#          [0.1467    , 0.1407    , 0.1407    , ..., 0.4138    ,
#           0.4138    , 0.41579998],
#          [0.13329999, 0.1334    , 0.1391    , ..., 0.6331    ,
#           0.50699997, 0.1796    ],
#          ...,
#          [0.1343    , 0.13419999, 0.13419999, ..., 0.1915    ,
#           0.1551    , 0.2871    ],
#          [0.1382    , 0.1321    , 0.132     , ..., 0.3464    ,
#           0.2056    , 0.18769999],
#          [0.13149999, 0.13149999, 0.1326    , ..., 0.2545    ,
#           0.2269    , 0.21319999]]], shape=(1, 85, 165), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 1kB 37.87 37.88 37.88 37.88 ... 38.21 38.21 38.22
#    * y            (y) float64 680B 30.33 30.33 30.33 30.33 ... 30.16 30.16 30.16
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2007-01-14
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 85, x: 165)> Size: 56kB
#  array([[[0.1437    , 0.1425    , 0.14039999, ..., 0.14109999,
#           0.2479    , 0.38779998],
#          [0.1453    , 0.14109999, 0.14109999, ..., 0.4076    ,
#           0.4076    , 0.2992    ],
#          [0.1349    , 0.1405    , 0.1422    , ..., 0.6853    ,
#           0.6853    , 0.375     ],
#          ...,
#          [0.13419999, 0.13499999, 0.13499999, ..., 0.44849998,
#           0.144     , 0.53      ],
#          [0.1356    , 0.13059999, 0.1321    , ..., 0.226     ,
#           0.16849999, 0.18159999],
#          [0.12719999, 0.12789999, 0.1331    , ..., 0.1955    ,
#           0.183     , 0.20179999]]], shape=(1, 85, 165), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 1kB 37.87 37.88 37.88 37.88 ... 38.21 38.21 38.22
#    * y            (y) float64 680B 30.33 30.33 30.33 30.33 ... 30.16 30.16 30.16
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2007-01-16
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 85, x: 165)> Size: 56kB
#  array([[[0.14639999, 0.1406    , 0.1407    , ..., 0.1375    ,
#           0.1629    , 0.30179998],
#          [0.1415    , 0.1388    , 0.1388    , ..., 0.66279995,
#           0.66279995, 0.64879996],
#          [0.13769999, 0.1414    , 0.1407    , ..., 0.7154    ,
#           0.5657    , 0.4511    ],
#          ...,
#          [0.1364    , 0.133     , 0.133     , ..., 0.28489998,
#           0.1286    , 0.2995    ],
#          [0.12979999, 0.1283    , 0.1389    , ..., 0.3216    ,
#           0.16679999, 0.1819    ],
#          [0.1302    , 0.1364    , 0.14019999, ..., 0.17799999,
#           0.1731    , 0.1819    ]]], shape=(1, 85, 165), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 1kB 37.87 37.88 37.88 37.88 ... 38.21 38.21 38.22
#    * y            (y) float64 680B 30.33 30.33 30.33 30.33 ... 30.16 30.16 30.16
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2007-01-17
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 85, x: 165)> Size: 56kB
#  array([[[0.14739999, 0.1418    , 0.1419    , ..., 0.1523    ,
#           0.385     , 0.3947    ],
#          [0.1423    , 0.14379999, 0.14379999, ..., 0.39319998,
#           0.39319998, 0.41709998],
#          [0.1409    , 0.1398    , 0.14379999, ..., 0.6512    ,
#           0.5121    , 0.161     ],
#          ...,
#          [0.1337    , 0.1322    , 0.1322    , ..., 0.3714    ,
#           0.17369999, 0.3621    ],
# ...
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2020-01-22
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 85, x: 165)> Size: 56kB
#  array([[[0.1417    , 0.13939999, 0.1462    , ..., 0.1778    ,
#           0.1366    , 0.1407    ],
#          [0.1443    , 0.1467    , 0.1467    , ..., 0.1515    ,
#           0.1515    , 0.1443    ],
#          [0.146     , 0.14829999, 0.1498    , ..., 0.1515    ,
#           0.1416    , 0.137     ],
#          ...,
#          [0.1347    , 0.1354    , 0.1354    , ..., 0.2481    ,
#           0.1612    , 0.3094    ],
#          [0.1365    , 0.13159999, 0.13759999, ..., 0.4793    ,
#           0.1715    , 0.1504    ],
#          [0.1371    , 0.14199999, 0.1354    , ..., 0.42819998,
#           0.23529999, 0.15869999]]], shape=(1, 85, 165), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 1kB 37.87 37.88 37.88 37.88 ... 38.21 38.21 38.22
#    * y            (y) float64 680B 30.33 30.33 30.33 30.33 ... 30.16 30.16 30.16
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2020-01-24
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 85, x: 165)> Size: 56kB
#  array([[[0.1463    , 0.1432    , 0.1408    , ..., 0.1221    ,
#           0.12      , 0.14549999],
#          [0.1424    , 0.1378    , 0.1378    , ..., 0.1383    ,
#           0.1383    , 0.1417    ],
#          [0.139     , 0.14039999, 0.1372    , ..., 0.16319999,
#           0.1514    , 0.1204    ],
#          ...,
#          [0.1364    , 0.127     , 0.127     , ..., 0.1716    ,
#           0.1494    , 0.35209998],
#          [0.127     , 0.1334    , 0.1334    , ..., 0.1813    ,
#           0.1545    , 0.1709    ],
#          [0.1327    , 0.1327    , 0.1353    , ..., 0.191     ,
#           0.17539999, 0.2236    ]]], shape=(1, 85, 165), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 1kB 37.87 37.88 37.88 37.88 ... 38.21 38.21 38.22
#    * y            (y) float64 680B 30.33 30.33 30.33 30.33 ... 30.16 30.16 30.16
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2021-01-14
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 85, x: 165)> Size: 56kB
#  array([[[0.1437    , 0.1409    , 0.14199999, ..., 0.1125    ,
#           0.1109    , 0.14199999],
#          [0.1397    , 0.1416    , 0.1416    , ..., 0.14729999,
#           0.14729999, 0.1389    ],
#          [0.137     , 0.137     , 0.1416    , ..., 0.1549    ,
#           0.1389    , 0.1389    ],
#          ...,
#          [0.131     , 0.13069999, 0.13069999, ..., 0.1428    ,
#           0.1199    , 0.1091    ],
#          [0.1292    , 0.1314    , 0.1308    , ..., 0.134     ,
#           0.1396    , 0.1423    ],
#          [0.1284    , 0.1329    , 0.13319999, ..., 0.1226    ,
#           0.1017    , 0.1627    ]]], shape=(1, 85, 165), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 1kB 37.87 37.88 37.88 37.88 ... 38.21 38.21 38.22
#    * y            (y) float64 680B 30.33 30.33 30.33 30.33 ... 30.16 30.16 30.16
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2021-01-16
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 85, x: 165)> Size: 56kB
#  array([[[0.1437    , 0.1431    , 0.1406    , ..., 0.1204    ,
#           0.1204    , 0.1418    ],
#          [0.1399    , 0.1433    , 0.1433    , ..., 0.12199999,
#           0.12199999, 0.1391    ],
#          [0.1383    , 0.139     , 0.1408    , ..., 0.1471    ,
#           0.1392    , 0.13159999],
#          ...,
#          [0.1285    , 0.126     , 0.126     , ..., 0.1551    ,
#           0.1161    , 0.151     ],
#          [0.1217    , 0.1291    , 0.1355    , ..., 0.20989999,
#           0.1277    , 0.1396    ],
#          [0.126     , 0.1276    , 0.137     , ..., 0.12289999,
#           0.12289999, 0.1331    ]]], shape=(1, 85, 165), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 1kB 37.87 37.88 37.88 37.88 ... 38.21 38.21 38.22
#    * y            (y) float64 680B 30.33 30.33 30.33 30.33 ... 30.16 30.16 30.16
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2021-01-17
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 85, x: 165)> Size: 56kB
#  array([[[0.1433    , 0.1419    , 0.1365    , ..., 0.11849999,
#           0.1321    , 0.1321    ],
#          [0.13599999, 0.1373    , 0.1373    , ..., 0.1296    ,
#           0.1296    , 0.1349    ],
#          [0.13599999, 0.1409    , 0.13759999, ..., 0.1399    ,
#           0.139     , 0.12719999],
#          ...,
#          [0.127     , 0.1273    , 0.1273    , ..., 0.1963    ,
#           0.1353    , 0.15359999],
#          [0.12529999, 0.12719999, 0.1331    , ..., 0.24929999,
#           0.1397    , 0.1468    ],
#          [0.1284    , 0.1294    , 0.13499999, ..., 0.5261    ,
#           0.1924    , 0.1496    ]]], shape=(1, 85, 165), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 1kB 37.87 37.88 37.88 37.88 ... 38.21 38.21 38.22
#    * y            (y) float64 680B 30.33 30.33 30.33 30.33 ... 30.16 30.16 30.16
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2021-01-19
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 85, x: 165)> Size: 56kB
#  array([[[0.14029999, 0.1387    , 0.1409    , ..., 0.1231    ,
#           0.12539999, 0.1504    ],
#          [0.13499999, 0.1409    , 0.1409    , ..., 0.14649999,
#           0.14649999, 0.1467    ],
#          [0.1425    , 0.1454    , 0.1441    , ..., 0.1329    ,
#           0.14649999, 0.132     ],
#          ...,
#          [0.1358    , 0.1361    , 0.1361    , ..., 0.1678    ,
#           0.1678    , 0.2667    ],
#          [0.1339    , 0.1303    , 0.1382    , ..., 0.70129997,
#           0.2726    , 0.13859999],
#          [0.13499999, 0.1353    , 0.1384    , ..., 0.6189    ,
#           0.2555    , 0.14379999]]], shape=(1, 85, 165), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 1kB 37.87 37.88 37.88 37.88 ... 38.21 38.21 38.22
#    * y            (y) float64 680B 30.33 30.33 30.33 30.33 ... 30.16 30.16 30.16
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2021-01-20
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 85, x: 165)> Size: 56kB
#  array([[[0.1416    , 0.148     , 0.1441    , ..., 0.12459999,
#           0.1241    , 0.1494    ],
#          [0.1454    , 0.1406    , 0.1406    , ..., 0.1466    ,
#           0.1466    , 0.14209999],
#          [0.14479999, 0.1406    , 0.1391    , ..., 0.13769999,
#           0.13679999, 0.13159999],
#          ...,
#          [0.1327    , 0.1287    , 0.1287    , ..., 0.3196    ,
#           0.1284    , 0.19209999],
#          [0.1245    , 0.129     , 0.1302    , ..., 0.2767    ,
#           0.2767    , 0.12969999],
#          [0.13      , 0.1293    , 0.1317    , ..., 0.6904    ,
#           0.2916    , 0.1415    ]]], shape=(1, 85, 165), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 1kB 37.87 37.88 37.88 37.88 ... 38.21 38.21 38.22
#    * y            (y) float64 680B 30.33 30.33 30.33 30.33 ... 30.16 30.16 30.16
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2021-01-22
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 85, x: 165)> Size: 56kB
#  array([[[0.1399    , 0.1366    , 0.1409    , ..., 0.1182    ,
#           0.121     , 0.1444    ],
#          [0.137     , 0.1387    , 0.1387    , ..., 0.13589999,
#           0.13589999, 0.14199999],
#          [0.13939999, 0.14199999, 0.1416    , ..., 0.14029999,
#           0.1366    , 0.1179    ],
#          ...,
#          [0.1366    , 0.1334    , 0.1334    , ..., 0.1805    ,
#           0.1449    , 0.3055    ],
#          [0.12799999, 0.1366    , 0.1326    , ..., 0.5226    ,
#           0.3266    , 0.1495    ],
#          [0.1304    , 0.1304    , 0.13509999, ..., 0.5947    ,
#           0.2206    , 0.1601    ]]], shape=(1, 85, 165), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 1kB 37.87 37.88 37.88 37.88 ... 38.21 38.21 38.22
#    * y            (y) float64 680B 30.33 30.33 30.33 30.33 ... 30.16 30.16 30.16
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2021-01-24
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 85, x: 165)> Size: 56kB
#  array([[[0.12979999, 0.1301    , 0.1356    , ..., 0.1258    ,
#           0.1296    , 0.1296    ],
#          [0.12709999, 0.1354    , 0.1354    , ..., 0.1469    ,
#           0.1469    , 0.155     ],
#          [0.1309    , 0.1355    , 0.1312    , ..., 0.15879999,
#           0.1654    , 0.1285    ],
#          ...,
#          [0.1311    , 0.1265    , 0.1265    , ..., 0.3023    ,
#           0.16049999, 0.2193    ],
#          [0.1292    , 0.1204    , 0.1244    , ..., 0.59779996,
#           0.2857    , 0.2024    ],
#          [0.123     , 0.1245    , 0.1245    , ..., 0.32189998,
#           0.32189998, 0.2548    ]]], shape=(1, 85, 165), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 1kB 37.87 37.88 37.88 37.88 ... 38.21 38.21 38.22
#    * y            (y) float64 680B 30.33 30.33 30.33 30.33 ... 30.16 30.16 30.16
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2022-01-14
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 85, x: 165)> Size: 56kB
#  array([[[0.1471    , 0.14      , 0.1349    , ..., 0.1239    ,
#           0.1192    , 0.1651    ],
#          [0.1317    , 0.1309    , 0.1309    , ..., 0.1321    ,
#           0.1321    , 0.1321    ],
#          [0.1366    , 0.1366    , 0.1294    , ..., 0.1563    ,
#           0.1599    , 0.1329    ],
#          ...,
#          [0.13059999, 0.1317    , 0.1317    , ..., 0.3884    ,
#           0.1581    , 0.2339    ],
#          [0.1275    , 0.1287    , 0.1325    , ..., 0.4044    ,
#           0.4044    , 0.1827    ],
#          [0.1294    , 0.1294    , 0.1287    , ..., 0.47849998,
#           0.19579999, 0.1848    ]]], shape=(1, 85, 165), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 1kB 37.87 37.88 37.88 37.88 ... 38.21 38.21 38.22
#    * y            (y) float64 680B 30.33 30.33 30.33 30.33 ... 30.16 30.16 30.16
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2022-01-16
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 85, x: 165)> Size: 56kB
#  array([[[0.1398    , 0.1405    , 0.1392    , ..., 0.1286    ,
#           0.1127    , 0.1466    ],
#          [0.1329    , 0.1374    , 0.1374    , ..., 0.153     ,
#           0.153     , 0.1513    ],
#          [0.13769999, 0.1375    , 0.1369    , ..., 0.15359999,
#           0.16129999, 0.1371    ],
#          ...,
#          [0.1328    , 0.13159999, 0.13159999, ..., 0.1353    ,
#           0.1245    , 0.1524    ],
#          [0.12539999, 0.1319    , 0.1285    , ..., 0.22809999,
#           0.2023    , 0.1594    ],
#          [0.1287    , 0.1293    , 0.12889999, ..., 0.376     ,
#           0.1765    , 0.1716    ]]], shape=(1, 85, 165), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 1kB 37.87 37.88 37.88 37.88 ... 38.21 38.21 38.22
#    * y            (y) float64 680B 30.33 30.33 30.33 30.33 ... 30.16 30.16 30.16
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2022-01-17
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 85, x: 165)> Size: 56kB
#  array([[[0.13589999, 0.14029999, 0.1358    , ..., 0.15879999,
#           0.12459999, 0.1422    ],
#          [0.1375    , 0.1375    , 0.1375    , ..., 0.134     ,
#           0.134     , 0.1391    ],
#          [0.12969999, 0.13409999, 0.13409999, ..., 0.15689999,
#           0.16059999, 0.1469    ],
#          ...,
#          [0.12969999, 0.1291    , 0.1291    , ..., 0.1462    ,
#           0.1542    , 0.1994    ],
#          [0.1241    , 0.1264    , 0.1264    , ..., 0.3232    ,
#           0.3232    , 0.176     ],
#          [0.13069999, 0.1269    , 0.1312    , ..., 0.69119996,
#           0.25579998, 0.19029999]]], shape=(1, 85, 165), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 1kB 37.87 37.88 37.88 37.88 ... 38.21 38.21 38.22
#    * y            (y) float64 680B 30.33 30.33 30.33 30.33 ... 30.16 30.16 30.16
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2022-01-19
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 85, x: 165)> Size: 56kB
#  array([[[0.13509999, 0.1371    , 0.13759999, ..., 0.154     ,
#           0.1268    , 0.1428    ],
#          [0.1318    , 0.13949999, 0.13949999, ..., 0.1539    ,
#           0.1539    , 0.15339999],
#          [0.1361    , 0.14209999, 0.1414    , ..., 0.1911    ,
#           0.1863    , 0.13939999],
#          ...,
#          [0.1291    , 0.1366    , 0.1366    , ..., 0.13949999,
#           0.1366    , 0.1779    ],
#          [0.1292    , 0.13069999, 0.1355    , ..., 0.6813    ,
#           0.24839999, 0.1854    ],
#          [0.131     , 0.1399    , 0.1366    , ..., 0.686     ,
#           0.255     , 0.1838    ]]], shape=(1, 85, 165), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 1kB 37.87 37.88 37.88 37.88 ... 38.21 38.21 38.22
#    * y            (y) float64 680B 30.33 30.33 30.33 30.33 ... 30.16 30.16 30.16
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2022-01-20
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 85, x: 165)> Size: 56kB
#  array([[[0.1408    , 0.14469999, 0.14549999, ..., 0.2043    ,
#           0.11719999, 0.14729999],
#          [0.1435    , 0.1409    , 0.1409    , ..., 0.1329    ,
#           0.1329    , 0.1485    ],
#          [0.1364    , 0.13949999, 0.1408    , ..., 0.1591    ,
#           0.1504    , 0.1245    ],
#          ...,
#          [0.1284    , 0.1286    , 0.1286    , ..., 0.1669    ,
#           0.1388    , 0.16589999],
#          [0.1278    , 0.1308    , 0.1334    , ..., 0.4784    ,
#           0.1635    , 0.18769999],
#          [0.1285    , 0.1325    , 0.13499999, ..., 0.513     ,
#           0.19669999, 0.21319999]]], shape=(1, 85, 165), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 1kB 37.87 37.88 37.88 37.88 ... 38.21 38.21 38.22
#    * y            (y) float64 680B 30.33 30.33 30.33 30.33 ... 30.16 30.16 30.16
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2022-01-22
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 85, x: 165)> Size: 56kB
#  array([[[0.1336    , 0.1339    , 0.1339    , ..., 0.17549999,
#           0.13589999, 0.139     ],
#          [0.1319    , 0.1299    , 0.1299    , ..., 0.1704    ,
#           0.1704    , 0.14019999],
#          [0.1346    , 0.1336    , 0.1362    , ..., 0.1704    ,
#           0.15969999, 0.14      ],
#          ...,
#          [0.1362    , 0.1362    , 0.1362    , ..., 0.3096    ,
#           0.1433    , 0.1765    ],
#          [0.1362    , 0.13239999, 0.1378    , ..., 0.6023    ,
#           0.1969    , 0.169     ],
#          [0.1309    , 0.1345    , 0.1358    , ..., 0.41419998,
#           0.1981    , 0.1769    ]]], shape=(1, 85, 165), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 1kB 37.87 37.88 37.88 37.88 ... 38.21 38.21 38.22
#    * y            (y) float64 680B 30.33 30.33 30.33 30.33 ... 30.16 30.16 30.16
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2022-01-24
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area]

# %% [markdown]
# ## Combine Rasters
#
# Next, stack your arrays by date into a time series using the
# `xr.combine_by_coords()` function. You will have to tell it which
# dimension you want to stack your data in.

# %%
# Combine NDVI images from all dates
ndvi_da = xr.combine_by_coords(ndvi_das).resample(dict(date='YS')).mean() 
ndvi_da
# Out:
# <xarray.Dataset> Size: 1MB
# Dimensions:      (date: 22, y: 85, x: 165)
# Coordinates:
#     band         int64 8B 1
#   * x            (x) float64 1kB 37.87 37.88 37.88 37.88 ... 38.21 38.21 38.22
#   * y            (y) float64 680B 30.33 30.33 30.33 30.33 ... 30.16 30.16 30.16
#     spatial_ref  int64 8B 0
#   * date         (date) datetime64[ns] 176B 2001-01-01 2002-01-01 ... 2022-01-01
# Data variables:
#     NDVI         (date, y, x) float32 1MB 0.1336 0.1343 0.1339 ... 0.2285 0.1965

# %% [markdown]
# # STEP -1: Wrap up
#
# Don’t forget to store your variables so you can use them in other
# notebooks! Replace `var1` and `var2` with the variable you want to save,
# separated by spaces.

# %%
# %store ndvi_da
# Out:
# Stored 'ndvi_da' (Dataset)

# %% [markdown]
# Finally, be sure to `Restart` and `Run all` to make sure your notebook
# works all the way through!
